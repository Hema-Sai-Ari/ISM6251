# %% [markdown]
# # ICP01 JUPYTER INSTALL
# ## Hema Sai Ari- U59528014

# %% [markdown]
# ![WhatsApp%20Image%202023-02-10%20at%2021.16.09.jpg](attachment:WhatsApp%20Image%202023-02-10%20at%2021.16.09.jpg)
#
# Hello, I am Hema Sai Ari and I am from India

# %%
print("HELLO WORLD!")
# Out:
# HELLO WORLD!
